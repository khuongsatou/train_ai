# %%
# Step 1. Mount drive 
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# Step 2. Clone V3
# %cd /content/gdrive/My\ Drive/train/
# !git clone https://github.com/pjreddie/darknet
# Out:
# /content/gdrive/My Drive/train
# Cloning into 'darknet'...
# remote: Enumerating objects: 5910, done.
# remote: Total 5910 (delta 0), reused 0 (delta 0), pack-reused 5910
# Receiving objects: 100% (5910/5910), 6.33 MiB | 6.28 MiB/s, done.
# Resolving deltas: 100% (3917/3917), done.
# Checking out files: 100% (979/979), done.

# %%
# Step 3. Tạo file yolo.names
# %cd /content/gdrive/My\ Drive/train/darknet/
# !echo "top_left" > yolo.names
# !echo "top_right" >> yolo.names
# !echo "bottom_left" >> yolo.names
# !echo "bottom_right" >> yolo.names
# Out:
# /content/gdrive/My Drive/train/darknet

# %%
# Step 4. Tạo file yolo.data
# %cd /content/gdrive/My\ Drive/train/darknet
#!mkdir backup
# !echo classes=4 > yolo.data
# !echo train=train.txt >> yolo.data
# !echo valid=val.txt >> yolo.data
# !echo names=yolo.names >> yolo.data
# !echo backup=backup >> yolo.data
# Out:
# /content/gdrive/My Drive/train/darknet

# %%
# Step 5.0 Upload data trong thư mục data
# Step 5. Giải nén file data
# %cd /content/gdrive/My\ Drive/train/darknet/data
# !unzip data.zip

# %%
# Step 6. Tạo file train.txt và val.txt
# %cd /content/gdrive/My\ Drive/train/darknet

import glob2
import math  
import os
import numpy as np

files = []
for ext in ["*.png", "*.jpeg", "*.jpg"]:
  image_files = glob2.glob(os.path.join("data/data/", ext))
  files += image_files

nb_val = math.floor(len(files)*0.2)
rand_idx = np.random.randint(0, len(files), nb_val)

# Tạo file train.txt
with open("train.txt", "w") as f:
  for idx in np.arange(len(files)):
    if (os.path.exists(files[idx][:-3] + "txt")):
      f.write(files[idx]+'\n')

# Tạo file vali.txt
with open("val.txt", "w") as f:
  for idx in np.arange(len(files)):
    if (idx in rand_idx):
      f.write(files[idx]+'\n')
# Out:
# /content/gdrive/My Drive/train/darknet

# %%
# Kiểm lại
# Makefile
# examples/detector.c
# yolo.data
# yolo.names
# cfg/yolov3.cfg
# darknet53.conv.74
# train.txt
# val.txt

# %%
# Step 8. Make darknet
# %cd /content/gdrive/My\ Drive/train/darknet
# !rm darknet
# !make

# %%
#Step 10. Train
# %cd /content/gdrive/My\ Drive/train/darknet
# !./darknet detector train yolo.data cfg/yolov3.cfg backup/yolov3.backup
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
# Region 106 Avg IOU: 0.792212, Class: 0.999989, Obj: 0.964781, No Obj: 0.000264, .5R: 1.000000, .75R: 0.750000,  count: 16
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000001, .5R: -nan, .75R: -nan,  count: 0
# Region 94 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000000, .5R: -nan, .75R: -nan,  count: 0
# Region 106 Avg IOU: 0.794214, Class: 0.999820, Obj: 0.873033, No Obj: 0.000296, .5R: 1.000000, .75R: 0.625000,  count: 16
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000001, .5R: -nan, .75R: -nan,  count: 0
# Region 94 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000000, .5R: -nan, .75R: -nan,  count: 0
# Region 106 Avg IOU: 0.801045, Class: 0.995861, Obj: 0.783832, No Obj: 0.000274, .5R: 1.000000, .75R: 0.687500,  count: 16
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000001, .5R: -nan, .75R: -nan,  count: 0
# ...
